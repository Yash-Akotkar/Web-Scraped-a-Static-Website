# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://en.wikipedia.org/wiki/List_of_largest_companies_in_India"

page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

# %%
# print(soup)

# %%
# wikitable sortable jquery-tablesorter
table = soup.find_all('table')[0]

# %%
# print(table)

# %%
world_titles = table.find_all('th')

# %%
world_titles
# Out:
# [<th align="center" colspan="2">Rank
#  </th>,
#  <th align="center" colspan="2">Forbes <br/>2000 rank
#  </th>,
#  <th align="center">Name
#  </th>,
#  <th align="center">Headquarters
#  </th>,
#  <th align="center">Revenue<br/>(billions <br/>US$)
#  </th>,
#  <th align="center">Profit<br/>(billions <br/>US$)
#  </th>,
#  <th align="center">Assets<br/>(billions <br/>US$)
#  </th>,
#  <th align="center">Value<br/>(billions <br/>US$)
#  </th>,
#  <th align="center">Industry
#  </th>]

# %%
world_table_titles = [title.text.strip() for title in world_titles]
print(world_table_titles)
# Out:
# ['Rank', 'Forbes 2000 rank', 'Name', 'Headquarters', 'Revenue(billions US$)', 'Profit(billions US$)', 'Assets(billions US$)', 'Value(billions US$)', 'Industry']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns= world_table_titles)
df
# Out:
# Empty DataFrame
# Columns: [Rank, Forbes 2000 rank, Name, Headquarters, Revenue(billions US$), Profit(billions US$), Assets(billions US$), Value(billions US$), Industry]
# Index: []

# %%
column_data = table.find_all('tr')

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row = [data.text.strip() for data in row_data]
    individual_row_data = [individual_row[i] for i in range(11) if i not in [1,3]]
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#    Rank Forbes 2000 rank                                Name Headquarters  \
# 0     1               54                 Reliance Industries       Mumbai
# 1     2              130                          TATA Group       Mumbai
# 2     3              105                 State Bank of India       Mumbai
# 3     4              154                           HDFC Bank       Mumbai
# 4     5              205                          ICICI Bank       Mumbai
# 5     6              229     Oil and Natural Gas Corporation    New Delhi
# 6     7              269                                HDFC       Mumbai
# 7     8              358              Indian Oil Corporation    New Delhi
# 8     9              385           Tata Consultancy Services       Mumbai
# 9    10              408                          Tata Steel       Mumbai
# 10   11              432                           Axis Bank       Mumbai
# 11   12              484                        NTPC Limited    New Delhi
# 12   13              514                     Larsen & Toubro       Mumbai
# 13   14              539                             Infosys    Bangalore
# 14   15              574                       JSW Steel Ltd       Mumbai
# 15   16              593                     Vedanta Limited       Mumbai
# 16   17              615                    Bharat Petroleum       Mumbai
# 17   18              628                 Kotak Mahindra Bank       Mumbai
# 18   19              643                 Hindalco Industries       Mumbai
# 19   20              710                       Bharti Airtel    New Delhi
# 20   21              726                          Coal India      Kolkata
# 21   22              729                         Tata Motors       Mumbai
# 22   23              789           Power Finance Corporation    New Delhi
# 23   24              809                    HCL Technologies        Noida
# 24   25              820                               Wipro    Bangalore
# 25   26              822     Power Grid Corporation of India      Gurgaon
# 26   27              827                   Grasim Industries       Mumbai
# 27   28              846                         ITC Limited      Kolkata
# 28   29              876                       Bajaj Finserv         Pune
# 29   30              925                         Canara Bank    Bangalore
# 30   31              954                      Bank of Baroda     Vadodara
# 31   32             1000                 Union Bank of India       Mumbai
# 32   33             1041                Punjab National Bank    New Delhi
# 33   34             1063                 Mahindra & Mahindra       Mumbai
# 34   35             1171            Steel Authority of India    New Delhi
# 35   36             1215                                GAIL    New Delhi
# 36   37             1348                         Indian Bank      Chennai
# 37   38             1362                  Sun Pharmaceutical       Mumbai
# 38   39             1514  Indian Railway Finance Corporation    New Delhi
# 39   40             1453                   Adani Enterprises    Ahmedabad
# 40   41             1472                       IndusInd Bank       Mumbai
# 41   42             1525                       Bank of India       Mumbai
# 42   43             1489           Adani Ports & SEZ Limited    Ahmedabad
# 43   44             1570                  Adani Green Energy    Ahmedabad
# 44   45             1656                      Rajesh Exports    Bangalore
# 45   46             1687                        Asian Paints       Mumbai
# 46   47             1705                  Adani Transmission    Ahmedabad
# 47   48             1730                       Tech Mahindra         Pune
# 48   49             1746                     Adani Total Gas    Ahmedabad
# 49   50             1756                          Bajaj Auto         Pune
# 50   51             1759                               DMart       Mumbai
# 51   52             1759                 Adyar Ananda Bhavan      Chennai
#
#    Revenue(billions US$) Profit(billions US$) Assets(billions US$)  \
# 0                  86.85                 7.81               192.59
# 1                    150                  139                  160
# 2                  54.52                 4.32               696.51
# 3                  22.51                 5.11               280.16
# 4                  21.89                 3.01               226.39
# 5                  66.28                 6.00                75.51
# 6                  18.48                 2.91               118.61
# 7                  72.20                 3.72                51.73
# 8                  25.73                 5.14                18.68
# 9                  31.07                 5.01                34.62
# 10                 11.41                 1.71               152.12
# 11                 17.00                 2.17                55.00
# 12                 20.53                 1.12                40.82
# 13                 16.33                 2.97                15.56
# 14                  9.50                 0.50                17.40
# 15                 16.38                 2.63                 25.3
# 16                  43.2                 2.59                25.18
# 17                  7.92                 1.46                41.57
# 18                 24.33                 1.60                27.45
# 19                 14.98                0.406                48.72
# 20                 14.03                 2.06                 22.3
# 21                 39.04                −2.44                42.32
# 22                 10.15                 1.86               106.71
# 23                 11.19                 1.49                11.57
# 24                 10.07                 1.64                13.69
# 25                  5.61                 2.19                34.56
# 26                 12.35                 0.87                36.94
# 27                  7.91                 2.00                10.04
# 28                  8.64                 0.56                41.54
# 29                 12.68                 0.73               164.71
# 30                 12.06                 0.68               167.76
# 31                 11.28                 0.67               148.94
# 32                  12.1                 0.57               178.94
# 33                 11.59                 0.73                22.36
# 34                 12.98                 1.79                15.87
# 35                 10.98                 1.53                12.03
# 36                  6.17                 0.65                89.96
# 37                  5.10                 0.87                 9.30
# 38                  2.55                 0.82                58.03
# 39                  7.86                 0.09                11.09
# 40                  5.09                 0.58                51.26
# 41                  6.26                 0.39                98.51
# 42                  2.10                 0.67                11.36
# 43                  0.41                 0.01                 3.93
# 44                 30.00                 0.15                  2.7
# 45                  3.77                 0.41                 2.84
# 46                  1.49                 0.16                 6.11
# 47                  5.72                 0.69                 5.51
# 48                  0.35                 0.07                 0.50
# 49                  4.54                 0.83                 4.51
# 50                  4.00                 0.20                 1.93
# 51                  4.00                 0.20                 1.93
#
#    Value(billions US$)            Industry
# 0               228.63        Conglomerate
# 1                  350        Conglomerate
# 2                58.39             Banking
# 3                98.28             Banking
# 4                 67.9             Banking
# 5                28.62         Oil and gas
# 6                52.30          Financials
# 7                16.53         Oil and gas
# 8               172.79            Infotech
# 9                20.42      Iron and steel
# 10               31.32             Banking
# 11               20.32           Utilities
# 12               31.13       Capital goods
# 13               87.21            Infotech
# 14               20.10      Iron and steel
# 15               20.21   Metals and mining
# 16               11.16         Oil and gas
# 17               44.83             Banking
# 18               15.11   Metals and mining
# 19               56.80   Telecommunication
# 20               16.30   Metals and mining
# 21               22.12          Automotive
# 22                4.10          Financials
# 23               39.09            Infotech
# 24               38.44            Infotech
# 25               20.57           Utilities
# 26               14.77         Diversified
# 27               42.06      Consumer Goods
# 28               32.15          Financials
# 29                5.53             Banking
# 30                7.54             Banking
# 31                3.62             Banking
# 32                5.10             Banking
# 33               14.96          Automotive
# 34                5.48      Iron and steel
# 35                9.52         Oil and gas
# 36                2.63             Banking
# 37               28.97     Pharmaceuticals
# 38                3.83          Financials
# 39               32.70      Consumer Goods
# 40                9.72             Banking
# 41                2.66             Banking
# 42               24.12            Shipping
# 43               59.06    Renewable energy
# 44                2.50  Gems and jewellery
# 45               39.69           Chemicals
# 46               38.15           Utilities
# 47               16.61            Infotech
# 48               34.74         Oil and gas
# 49               13.79          Automotive
# 50               34.12              Retail
# 51               34.12              Retail

# %%
df.to_csv(r'E:\Companies.csv', index=False)
